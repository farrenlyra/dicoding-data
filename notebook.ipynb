# %% [markdown]
# <a href="https://colab.research.google.com/github/farrenlyra/dicoding-data/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Farren Lyrananda Rachman
# - **Email:** farrenlnr@gmail.com
# - **ID Dicoding:** farrenlyrananda

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apakah terdapat perbedaan yang signifikan dalam pola penyewaan sepeda antara hari kerja dan akhir pekan?
# - Bagaimana pola penyewaan sepeda bervariasi berdasarkan faktor lingkungan dan musiman, seperti cuaca, musim, dan hari dalam seminggu?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Pada tahap ini akan dilakukan pengumpulan data, karena saya memilih **Bike Sharing Dataset**, maka saya mengimpor file **day.csv** dan **hr.csv**

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# ####Insight

# %% [markdown]
# Load Tabel day

# %%
day_df = pd.read_csv("/content/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Load Tabel hour

# %%
hour_df = pd.read_csv("/content/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai day_df

# %% [markdown]
# 1. **Mengecek Tipe Data day_df**

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# 2. **Mengecek Missing Values**

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Pada dataset **day_df** tidak terdapat missing values.

# %% [markdown]
# 3. **Mengecek Duplicate Data**

# %%
print("Jumlah duplikasi data: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi data:  0

# %% [markdown]
# Pada dataset **day_df** tidak terdapat duplicate data, yang berarti data bersifat unik.

# %% [markdown]
# 4. **Mengecek Statistik**

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# Pada dataset **day_df** tidak terdapat keanehan dari statistiknya.

# %% [markdown]
# Menilai hour_df

# %% [markdown]
# 1. **Mengecek Tipe Data hour_df**

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# 2. **Mengecek Missing Values**

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Pada dataset **hour_df** tidak terdapat missing values.

# %% [markdown]
# 3. **Mengecek Duplicate Data**

# %%
print("Jumlah duplikasi data: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi data:  0

# %% [markdown]
# Pada dataset **hour_df** tidak terdapat duplicate data, yang berarti data bersifat unik.

# %% [markdown]
# 4. **Mengecek Statistik**

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# Pada dataset **hour_df** tidak terdapat keanehan dari statistiknya.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# 1. **Menghapus Tabel yang Tidak Diperlukan**

# %% [markdown]
# Kita tidak memerlukan data dengan resolusi jam (hourly), cukup menggunakan data harian (daily) karena pertanyaan bisnis lebih fokus pada perbandingan pola antar hari, cuaca, dan musim.

# %%
del hour_df

# %% [markdown]
# 2. **Menghapus Kolom yang Tidak Diperlukan**

# %% [markdown]
# Kolom yang tidak berkaitan langsung dengan pertanyaan bisnis akan dihapus. Berdasarkan pertanyaan bisnis, kita tidak membutuhkan:
#
# **instant**: Indeks catatan ini tidak memberikan informasi yang relevan.
#
# **windspeed**: Tidak ada pertanyaan yang berfokus pada pengaruh kecepatan angin terhadap jumlah penyewaan.

# %%
drop_col = ['instant', 'windspeed']
for i in day_df.columns:
    if i in drop_col:
        day_df.drop(labels=i, axis=1, inplace=True)

day_df.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        temp     atemp       hum  casual  registered   cnt
# 0  0.344167  0.363625  0.805833     331         654   985
# 1  0.363478  0.353739  0.696087     131         670   801
# 2  0.196364  0.189405  0.437273     120        1229  1349
# 3  0.200000  0.212122  0.590435     108        1454  1562
# 4  0.226957  0.229270  0.436957      82        1518  1600

# %% [markdown]
# 3. **Mengubah Judul Kolom**

# %% [markdown]
# Kita akan mengubah nama beberapa kolom agar lebih mudah dipahami dan konsisten dengan pertanyaan bisnis. Selain itu, kita akan mengubah tipe data yang lebih sesuai, misalnya, mengubah angka musiman atau hari dalam seminggu menjadi bentuk kategori yang lebih mudah dibaca.

# %% [markdown]
# **Mengganti Nama Kolom**

# %%
day_df.rename(columns={
    'dteday': 'date',
    'yr': 'year',
    'mnth': 'month',
    'weathersit': 'weather_condition',
    'cnt': 'total_count'
}, inplace=True)
day_df.head()
# Out:
#          date  season  year  month  holiday  weekday  workingday  \
# 0  2011-01-01       1     0      1        0        6           0
# 1  2011-01-02       1     0      1        0        0           0
# 2  2011-01-03       1     0      1        0        1           1
# 3  2011-01-04       1     0      1        0        2           1
# 4  2011-01-05       1     0      1        0        3           1
#
#    weather_condition      temp     atemp       hum  casual  registered  \
# 0                  2  0.344167  0.363625  0.805833     331         654
# 1                  2  0.363478  0.353739  0.696087     131         670
# 2                  1  0.196364  0.189405  0.437273     120        1229
# 3                  1  0.200000  0.212122  0.590435     108        1454
# 4                  1  0.226957  0.229270  0.436957      82        1518
#
#    total_count
# 0          985
# 1          801
# 2         1349
# 3         1562
# 4         1600

# %% [markdown]
# **Mengubah Angka menjadi Label Kategori**

# %% [markdown]
# Agar lebih mudah dianalisis, kita akan mengonversi nilai angka pada beberapa kolom menjadi deskripsi kategori.

# %%
day_df['month'] = day_df['month'].map({
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
    7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
})

day_df['season'] = day_df['season'].map({
    1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'
})

day_df['weekday'] = day_df['weekday'].map({
    0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'
})

day_df['weather_condition'] = day_df['weather_condition'].map({
    1: 'Clear/Partly Cloudy',
    2: 'Misty/Cloudy',
    3: 'Light Snow/Rain',
    4: 'Severe Weather'
})

day_df.head()
# Out:
#          date  season  year month  holiday weekday  workingday  \
# 0  2011-01-01  Spring     0   Jan        0     Sat           0
# 1  2011-01-02  Spring     0   Jan        0     Sun           0
# 2  2011-01-03  Spring     0   Jan        0     Mon           1
# 3  2011-01-04  Spring     0   Jan        0     Tue           1
# 4  2011-01-05  Spring     0   Jan        0     Wed           1
#
#      weather_condition      temp     atemp       hum  casual  registered  \
# 0         Misty/Cloudy  0.344167  0.363625  0.805833     331         654
# 1         Misty/Cloudy  0.363478  0.353739  0.696087     131         670
# 2  Clear/Partly Cloudy  0.196364  0.189405  0.437273     120        1229
# 3  Clear/Partly Cloudy  0.200000  0.212122  0.590435     108        1454
# 4  Clear/Partly Cloudy  0.226957  0.229270  0.436957      82        1518
#
#    total_count
# 0          985
# 1          801
# 2         1349
# 3         1562
# 4         1600

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               731 non-null    object
#  1   season             731 non-null    object
#  2   year               731 non-null    int64
#  3   month              731 non-null    object
#  4   holiday            731 non-null    int64
#  5   weekday            731 non-null    object
#  6   workingday         731 non-null    int64
#  7   weather_condition  731 non-null    object
#  8   temp               731 non-null    float64
#  9   atemp              731 non-null    float64
#  10  hum                731 non-null    float64
#  11  casual             731 non-null    int64
#  12  registered         731 non-null    int64
#  13  total_count        731 non-null    int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 80.1+ KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# 1. Kelompokkan penyewa sepeda (casual dan registered) berdasarkan bulan

# %%
day_df.groupby(by='month').agg({
    'total_count': ['max', 'min', 'mean', 'sum']
})
# Out:
#       total_count
#               max   min         mean     sum
# month
# Apr          7460   795  4484.900000  269094
# Aug          7865  1115  5664.419355  351194
# Dec          6606   441  3403.806452  211036
# Feb          5062  1005  2655.298246  151352
# Jan          4521   431  2176.338710  134933
# Jul          8173  3285  5563.677419  344948
# Jun          8120  3767  5772.366667  346342
# Mar          8362   605  3692.258065  228920
# May          8294  2633  5349.774194  331686
# Nov          6852  1495  4247.183333  254831
# Oct          8156    22  5199.225806  322352
# Sep          8714  1842  5766.516667  345991

# %% [markdown]
# Kesimpulan: Bulan dengan rata-rata penyewaan terbesar adalah bulan Juni. Sementara itu, bulan Januari memiliki rata-rata terkecil.

# %% [markdown]
# 2. Kelompokkan penyewa sepeda berdasarkan kondisi cuaca

# %%
day_df.groupby(by='weather_condition').agg({
    'total_count': ['max', 'min', 'mean', 'sum']
})
# Out:
#                     total_count
#                             max  min         mean      sum
# weather_condition
# Clear/Partly Cloudy        8714  431  4876.786177  2257952
# Light Snow/Rain            4639   22  1803.285714    37869
# Misty/Cloudy               8362  605  4035.862348   996858

# %% [markdown]
# Kesimpulan: Para penyewa cenderung menyewa sepeda pada saat cuaca cerah atau mendung. Penyewaan jauh lebih sedikit saat salju turun atau hujan ringan.

# %% [markdown]
# 3. Kelompokkan penyewa sepeda berdasarkan hari libur

# %%
day_df.groupby(by='holiday').agg({
    'total_count': ['max', 'min', 'mean', 'sum']
})
# Out:
#         total_count
#                 max   min         mean      sum
# holiday
# 0              8714    22  4527.104225  3214244
# 1              7403  1000  3735.000000    78435

# %% [markdown]
# Kesimpulan: Penyewa lebih banyak menyewa sepeda saat bukan hari libur dibandingkan pada hari-hari libur.

# %% [markdown]
# 4. Bandingkan penyewaan sepeda pada hari kerja (weekday) dan akhir pekan (weekend)

# %%
day_df.groupby(by='weekday').agg({
    'total_count': ['max', 'min', 'mean']
})
# Out:
#         total_count
#                 max   min         mean
# weekday
# Fri            8362  1167  4690.288462
# Mon            7525    22  4338.123810
# Sat            8714   627  4550.542857
# Sun            8227   605  4228.828571
# Thu            7804   431  4667.259615
# Tue            7767   683  4510.663462
# Wed            8173   441  4548.538462

# %% [markdown]
# Kesimpulan: Hari Jumat memiliki rata-rata penyewaan tertinggi, diikuti oleh Kamis dan Sabtu. Minggu dan Senin memiliki rata-rata penyewaan yang lebih rendah.

# %% [markdown]
# 5. Kelompokkan penyewa sepeda berdasarkan hari kerja (workingday)

# %%
day_df.groupby(by='workingday').agg({
    'total_count': ['max', 'min', 'mean']
})
# Out:
#            total_count
#                    max  min         mean
# workingday
# 0                 8714  605  4330.168831
# 1                 8362   22  4584.820000

# %% [markdown]
# Kesimpulan: Penyewaan sepeda pada hari kerja lebih tinggi dibandingkan dengan hari non-kerja, namun perbedaannya tidak terlalu signifikan.

# %% [markdown]
# 6. Kelompokkan penyewa sepeda berdasarkan musim (season)

# %%
day_df.groupby(by='season').agg({
    'casual': 'mean',
    'registered': 'mean',
    'total_count': ['max', 'min', 'mean']
})
# Out:
#              casual   registered total_count
#                mean         mean         max   min         mean
# season
# Fall    1202.611702  4441.691489        8714  1115  5644.303191
# Spring   334.928177  2269.204420        7836   431  2604.132597
# Summer  1106.097826  3886.233696        8362   795  4992.331522
# Winter   729.112360  3999.050562        8555    22  4728.162921

# %% [markdown]
# Kesimpulan: Penyewaan sepeda tertinggi terjadi pada musim gugur (Fall) dengan rata-rata tertinggi baik dari penyewa casual maupun registered. Penyewaan terendah ada di musim semi (Spring).

# %% [markdown]
# 7. Kelompokkan suhu (temp), suhu persepsi (atemp), dan kelembaban (hum) berdasarkan musim

# %%
day_df.groupby(by='season').agg({
    'temp': ['max', 'min', 'mean'],
    'atemp': ['max', 'min', 'mean'],
    'hum': ['max', 'min', 'mean']
})
# Out:
#             temp                         atemp                           hum  \
#              max       min      mean       max       min      mean       max
# season
# Fall    0.861667  0.469167  0.706309  0.840896  0.242400  0.655898  0.939565
# Spring  0.572500  0.059130  0.297748  0.548617  0.079070  0.296914  0.948261
# Summer  0.808333  0.253043  0.544405  0.757579  0.250339  0.520307  0.922500
# Winter  0.657500  0.220833  0.422906  0.607975  0.227913  0.415539  0.972500
#
#
#              min      mean
# season
# Fall    0.360000  0.633482
# Spring  0.000000  0.582903
# Summer  0.254167  0.626948
# Winter  0.333478  0.668719

# %% [markdown]
# Kesimpulan:
#
# *   Suhu dan suhu persepsi tertinggi terjadi pada musim gugur (Fall).
# *   Kelembaban tertinggi ada pada musim dingin (Winter).

# %% [markdown]
# 8. Hubungan antara casual, registered, dan total_count

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
correlation_matrix = day_df.corr(numeric_only=True)
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, mask=mask, annot=True, fmt=".2f", cmap='coolwarm', ax=ax)
plt.show()

# %% [markdown]
# Kesimpulan:
#
# * **atemp dan temp sangat berkorelasi (0.99)**. Ini berarti temperatur yang dirasakan (atemp) memiliki hubungan yang hampir sempurna dengan suhu aktual (temp), yang masuk akal karena keduanya sangat berhubungan.
#
# * **hum memiliki korelasi lemah dengan temp dan atemp (0.13 dan 0.14)**. Ini menunjukkan bahwa kelembapan (hum) tidak memiliki hubungan yang signifikan dengan suhu ataupun temperatur yang dirasakan.
#
# * **casual cukup berkorelasi dengan temp dan atemp (0.54)**. Ini berarti bahwa jumlah penyewa sepeda kasual (casual) meningkat seiring dengan meningkatnya suhu, dan orang cenderung menyewa sepeda lebih banyak ketika cuaca lebih hangat.
#
# * **casual memiliki sedikit korelasi negatif dengan hum (-0.08)**. Ini menunjukkan bahwa semakin tinggi kelembapan, sedikit lebih rendah jumlah penyewa kasual, meskipun pengaruhnya relatif kecil.
#
# * **registered memiliki pola yang mirip dengan casual, dengan korelasi moderat terhadap temp dan atemp (0.54 dan 0.54), namun memiliki korelasi yang lebih kuat dengan casual (0.40)**. Ini menunjukkan bahwa faktor cuaca juga memengaruhi penyewa sepeda yang terdaftar (registered) secara serupa dengan penyewa kasual.
#
# * **total_count berkorelasi kuat dengan temp, atemp, casual, dan registered (0.63, 0.63, 0.67, dan 0.95)**. Ini berarti jumlah total penyewaan sepeda sangat dipengaruhi oleh suhu, penyewa kasual, dan penyewa terdaftar. Faktor kelembapan (hum) memiliki korelasi yang sedikit negatif dengan total penyewaan (-0.10).
#
# Dari analisis ini, kita dapat menyimpulkan bahwa cuaca, terutama suhu, memiliki pengaruh signifikan terhadap jumlah penyewaan sepeda, baik dari penyewa kasual maupun yang terdaftar.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apakah terdapat perbedaan yang signifikan dalam pola penyewaan sepeda antara hari kerja dan akhir pekan?

# %%
sns.barplot(x='workingday', y='total_count', data=day_df, estimator='mean')

plt.title('Perbandingan Rata-rata Penyewaan Sepeda Antara Hari Kerja dan Akhir Pekan')
plt.xlabel('Hari Kerja (1 = Hari Kerja, 0 = Akhir Pekan)')
plt.ylabel('Rata-rata Jumlah Penyewaan Sepeda')
plt.show()

# %% [markdown]
# Grafik menunjukkan bahwa rata-rata penyewaan sepeda sedikit lebih tinggi pada hari kerja dibandingkan akhir pekan, dengan penyewaan pada hari kerja di atas 4500 dan akhir pekan sedikit di bawahnya, kemungkinan karena penggunaan sepeda yang lebih banyak untuk keperluan rutin seperti bekerja atau sekolah pada hari kerja.

# %% [markdown]
# ### Pertanyaan 2: Bagaimana pola penyewaan sepeda bervariasi berdasarkan faktor lingkungan dan musiman, seperti cuaca, musim, dan hari dalam seminggu?

# %%
sns.lineplot(x='weekday', y='total_count', hue='season', data=day_df)

plt.title('Tren Penyewaan Sepeda Berdasarkan Musim dan Hari dalam Seminggu')
plt.xlabel('Hari dalam Seminggu (0 = Minggu, 6 = Sabtu)')
plt.ylabel('Jumlah Penyewaan Sepeda')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Grafik menunjukkan bahwa jumlah penyewaan sepeda lebih tinggi pada musim panas dan semi dibandingkan musim gugur dan dingin, di mana musim dingin memiliki penyewaan terendah. Tren penyewaan juga lebih tinggi pada hari kerja (Senin hingga Jumat) dibandingkan akhir pekan, dengan lonjakan tajam pada hari Selasa di semua musim. Musim panas memiliki puncak penyewaan yang lebih stabil sepanjang minggu, sementara musim dingin menunjukkan jumlah penyewaan yang lebih rendah dan fluktuatif.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# 1. RFM Analysis

# %%
day_df['date'] = pd.to_datetime(day_df['date'])
current_date = day_df['date'].max()

# Group by dan agregasi data
rfm_df = day_df.groupby('date').agg({
    'date': lambda x: (current_date - x.max()).days,  # Menghitung recency
    'total_count': 'sum'  # Gantilah 'total_count' dengan nama kolom yang benar
}).rename(columns={'date': 'recency', 'total_count': 'monetary'})  # Ubah nama kolom

# Menambahkan kolom frequency
rfm_df['frequency'] = rfm_df['monetary']
print(rfm_df.head())
# Out:
#             recency  monetary  frequency
# date
# 2011-01-01      730       985        985
# 2011-01-02      729       801        801
# 2011-01-03      728      1349       1349
# 2011-01-04      727      1562       1562
# 2011-01-05      726      1600       1600

# %% [markdown]
# 1. Recency: Mengukur berapa hari yang telah berlalu sejak tanggal penyewaan terakhir. Dalam hal ini, perbedaan dihitung dari tanggal maksimal di dataset (current_date).
# 2. Monetary: Total penyewaan sepeda yang terjadi pada hari tersebut.
# 3. Frequency: Karena tidak ada pengelompokan per pelanggan, nilai Monetary digunakan sebagai proxy untuk Frequency (jumlah total transaksi/penyewaan yang terjadi per hari).

# %%
day_df['date'] = pd.to_datetime(day_df['date'])
current_date = day_df['date'].max()

rfm_df = day_df.groupby('date').agg({
    'date': lambda x: (current_date - x.max()).days,
    'total_count': 'sum'
}).rename(columns={'date': 'recency', 'total_count': 'monetary'})

rfm_df['frequency'] = rfm_df['monetary']

# Plot distribusi Recency
plt.figure(figsize=(10, 5))
sns.histplot(rfm_df['recency'], bins=30, kde=True, color='blue')
plt.title('Distribusi Recency (Hari Sejak Penyewaan Terakhir)')
plt.xlabel('Recency (Hari)')
plt.ylabel('Frekuensi')
plt.show()

# Plot distribusi Monetary
plt.figure(figsize=(10, 5))
sns.histplot(rfm_df['monetary'], bins=30, kde=True, color='green')
plt.title('Distribusi Monetary (Total Penyewaan)')
plt.xlabel('Monetary (Total Penyewaan)')
plt.ylabel('Frekuensi')
plt.show()

# Plot distribusi Frequency
plt.figure(figsize=(10, 5))
sns.histplot(rfm_df['frequency'], bins=30, kde=True, color='red')
plt.title('Distribusi Frequency (Jumlah Transaksi)')
plt.xlabel('Frequency (Jumlah Transaksi)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berikut adalah perubahan dengan struktur yang lebih berbeda:
#
# 1. **Distribusi Recency (Hari Sejak Penyewaan Terakhir):**
#    - Hasil distribusi ini menunjukkan pola yang cukup merata, menandakan bahwa penyewaan sepeda berlangsung konsisten dalam rentang waktu yang ditentukan. Meskipun terdapat sedikit penurunan pada nilai recency yang lebih besar, secara umum, penyebarannya tetap stabil.
#    - Tidak terdapat variasi besar dalam jarak waktu antara penyewaan sepeda terakhir di dataset.
#
# 2. **Distribusi Monetary (Total Penyewaan):**
#    - Distribusi ini mendekati pola normal, dengan titik tertinggi berada di kisaran 4000 hingga 5000 penyewaan. Ini menggambarkan bahwa pada sebagian besar hari, jumlah total penyewaan sepeda berada di rentang tersebut.
#    - Beberapa outlier ditemukan di bagian ekstrem, menunjukkan bahwa ada hari-hari dengan penggunaan sepeda yang jauh lebih rendah atau lebih tinggi dari biasanya.
#
# 3. **Distribusi Frequency (Jumlah Transaksi):**
#    - Pola distribusi frekuensi memiliki kemiripan dengan distribusi monetary karena keduanya didasarkan pada data yang sama dalam analisis ini.
#    - Sebagian besar transaksi harian berada dalam rentang yang serupa, dengan puncak di sekitar 4000-5000 transaksi per hari.

# %% [markdown]
# 2. Clustering dengan Manual Grouping dan Binning

# %% [markdown]
# a. Manual Grouping Berdasarkan Total Penyewaan (Total)

# %%
day_df['Usage_Category'] = pd.cut(day_df['total_count'],
                                  bins=[0, 50, 100, 200, np.inf],
                                  labels=['Low', 'Medium', 'High', 'Very High'])

print(day_df[['total_count', 'Usage_Category']].head())
# Out:
#    total_count Usage_Category
# 0          985      Very High
# 1          801      Very High
# 2         1349      Very High
# 3         1562      Very High
# 4         1600      Very High

# %% [markdown]
# Menampilkan semua data yang berkategori Very High karena nilai total dari seluruh penyewaan merupakan lebih besar dari 200.

# %% [markdown]
# b. Binning Berdasarkan Waktu (Misalnya Bulan)

# %%
day_df['date'] = pd.to_datetime(day_df['date'])

day_df['month_group'] = pd.cut(day_df['date'].dt.month,
                               bins=[0, 3, 6, 9, 12],
                               labels=['Q1 (Jan-Mar)', 'Q2 (Apr-Jun)', 'Q3 (Jul-Sep)', 'Q4 (Oct-Dec)'],
                               right=True,
                               include_lowest=True)

q1 = day_df[day_df['month_group'] == 'Q1 (Jan-Mar)'].head(5)
q2 = day_df[day_df['month_group'] == 'Q2 (Apr-Jun)'].head(5)
q3 = day_df[day_df['month_group'] == 'Q3 (Jul-Sep)'].head(5)
q4 = day_df[day_df['month_group'] == 'Q4 (Oct-Dec)'].head(5)

quarters_data = pd.concat([q1, q2, q3, q4])
print(quarters_data)
# Out:
#           date  season  year month  holiday weekday  workingday  \
# 0   2011-01-01  Spring     0   Jan        0     Sat           0
# 1   2011-01-02  Spring     0   Jan        0     Sun           0
# 2   2011-01-03  Spring     0   Jan        0     Mon           1
# 3   2011-01-04  Spring     0   Jan        0     Tue           1
# 4   2011-01-05  Spring     0   Jan        0     Wed           1
# 90  2011-04-01  Summer     0   Apr        0     Fri           1
# 91  2011-04-02  Summer     0   Apr        0     Sat           0
# 92  2011-04-03  Summer     0   Apr        0     Sun           0
# 93  2011-04-04  Summer     0   Apr        0     Mon           1
# 94  2011-04-05  Summer     0   Apr        0     Tue           1
# 181 2011-07-01    Fall     0   Jul        0     Fri           1
# 182 2011-07-02    Fall     0   Jul        0     Sat           0
# 183 2011-07-03    Fall     0   Jul        0     Sun           0
# 184 2011-07-04    Fall     0   Jul        1     Mon           0
# ...

# %% [markdown]
# Data berhasil dikelompokkan ke dalam kuartal Q1, Q2, Q3, dan Q4, masing-masing menampilkan 5 baris. Semua data menunjukkan kategori penggunaan sepeda Very High untuk setiap kuartal, dan pengelompokan berdasarkan kuartal dilakukan dengan benar sesuai bulan.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Conclution pertanyaan 1**
#
# Hari Kerja vs Akhir Pekan: Rata-rata penyewaan sepeda sedikit lebih tinggi pada hari kerja dibandingkan akhir pekan. Rata-rata penyewaan sepeda pada hari kerja berada di atas 4500, sementara pada akhir pekan sedikit lebih rendah dari angka tersebut.
#
# Perbedaan Jumlah Penyewaan: Meskipun perbedaan jumlah penyewaan sepeda antara hari kerja dan akhir pekan tidak terlalu signifikan, data menunjukkan kecenderungan bahwa penyewaan sepeda lebih tinggi pada hari kerja. Hal ini bisa disebabkan oleh penggunaan sepeda untuk aktivitas rutin, seperti pergi bekerja atau sekolah.
#
# Kesimpulannya, terdapat perbedaan pola penyewaan sepeda antara hari kerja dan akhir pekan, dengan sedikit lebih banyak penyewaan terjadi pada hari kerja. Namun, perbedaan ini tidak terlalu besar.
# - **Conclution pertanyaan 2**
#
# Berdasarkan grafik yang menggambarkan tren penyewaan sepeda berdasarkan musim dan hari dalam seminggu:
#
# Jumlah Penyewaan per Musim:
#
# Summer (Musim Panas) dan Spring (Musim Semi) memiliki rata-rata penyewaan sepeda yang lebih tinggi dibandingkan musim lainnya.
#
# Winter (Musim Dingin) memiliki jumlah penyewaan paling rendah, yang mungkin disebabkan oleh cuaca dingin yang mengurangi minat bersepeda.
#
# Fall (Musim Gugur) menunjukkan tingkat penyewaan yang sedang, lebih rendah dari musim panas tetapi lebih tinggi dari musim dingin.
# Tren Penyewaan Berdasarkan Hari dalam Seminggu:
#
# Di semua musim, penyewaan cenderung lebih tinggi pada hari kerja (Senin hingga Jumat) dibandingkan akhir pekan (Sabtu dan Minggu).
#
# Ada peningkatan penyewaan yang mencolok pada hari Selasa, menunjukkan pola penggunaan sepeda yang lebih intens di awal minggu kerja.
# Perbedaan Antar Musim:
#
# Pada musim panas, penyewaan lebih stabil dan tinggi sepanjang minggu, sementara di musim dingin, jumlah penyewaan lebih rendah dan lebih fluktuatif.
